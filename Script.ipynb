# %%
## Create a web scraping script that can extract Product related information from any 2 e-commerce websites such as product names, product category and other product details along with price.
# Use the sample screenshot for your reference to generate a mapping of Product category and GST Rate. (Do not only use the sample CSV file but add your own records based on the products fetched.)

# 1. Add GST info such as GST rates by importing a csv/excel file which has a mapping of product categories and GST applicable. Add this info against each product.
# 2. Use pandas to clean / process the data
# 3. Generate insights for average GST rate by product category. Perform any 1 more anaylsis of your choice.
# 4. Scrape a list of 50 products across multiple categories.
# 5. Allow to export any one report as a csv.

# Completion of the test is defiantly a must, even if the time has elapsed and any additional features is a bonus.

# %%
import csv
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
gst_rates = {}

def scrape_product(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.content,'html.parser')
    
    print(page)
    print(soup)
    products = []
    
    for product_div in soup.find_all('div', class_='product'):
        product = {}
        product['name'] = product_div.find('h3').text
        product['category'] = product_div.find('span',class_='category').text
        product['details'] = product_div.find('p',class_='details').text
        product['price'] = product_div.find('span',class_='price').text
        product['gst_rate'] = gst_rates.get(product[category],None)
        products.append(product)
        
    return products

# %%
url1 = 'https://monsterhost.com/'
product1 =scrape_product(url1)
url2 = 'https://www.flipkart.com/cameras/dslr-mirrorless'
product2 = scrape_product(url2)
# Out:
# <Response [200]>
# <!DOCTYPE html>
#
# <!--[if !IE]><!--> <html lang="en" prefix="og: https://ogp.me/ns#" xmlns:addthis="https://www.addthis.com/help/api-spec" xmlns:fb="https://www.facebook.com/2008/fbml"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <link href="https://monsterhost.com/nl/" hreflang="nl" rel="alternate"/>
# <link href="https://monsterhost.com" hreflang="en" rel="alternate"/>
# <link href="https://monsterhost.com/wp-content/cache/autoptimize/css/autoptimize_8a33b614bc565655d9672f10e7a7b048.css" media="all" rel="stylesheet"/><title>Fastest Web Hosting Services | Buy High Quality Hosting</title><link as="style" href="https://fonts.googleapis.com/css?family=Nunito%20Sans%3A300%7CNunito%20Sans%3A700%2C900%7CRoboto%3A100%2C100italic%2C200%2C200italic%2C300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C600%2C600italic%2C700%2C700italic%2C800%2C800italic%2C900%2C900italic%7CRoboto%20Slab%3A100%2C100italic%2C200%2C200italic%2C300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C600%2C600italic%2C700%2C700italic%2C800%2C800italic%2C900%2C900italic%7CPoppins%3A300&amp;display=swap" rel="preload"/><link href="https://fonts.googleapis.com/css?family=Nunito%20Sans%3A300%7CNunito%20Sans%3A700%2C900%7CRoboto%3A100%2C100italic%2C200%2C200italic%2C300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C600%2C600italic%2C700%2C700italic%2C800%2C800italic%2C900%2C900italic%7CRoboto%20Slab%3A100%2C100italic%2C200%2C200italic%2C300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C600%2C600italic%2C700%2C700italic%2C800%2C800italic%2C900%2C900italic%7CPoppins%3A300&amp;display=swap" media="print" onload="this.media='all'" rel="stylesheet"/><noscript><link href="https://fonts.googleapis.com/css?family=Nunito%20Sans%3A300%7CNunito%20Sans%3A700%2C900%7CRoboto%3A100%2C100italic%2C200%2C200italic%2C300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C600%2C600italic%2C700%2C700italic%2C800%2C800italic%2C900%2C900italic%7CRoboto%20Slab%3A100%2C100italic%2C200%2C200italic%2C300%2C300italic%2C400%2C400italic%2C500%2C500italic%2C600%2C600italic%2C700%2C700italic%2C800%2C800italic%2C900%2C900italic%7CPoppins%3A300&amp;display=swap" rel="stylesheet"/></noscript><link as="style" href="https://fonts.googleapis.com/css2?family=Nunito+Sans:wght@300;700;900&amp;display=swap" rel="preload"/><link href="https://fonts.googleapis.com/css2?family=Nunito+Sans:wght@300;700;900&amp;display=swap" media="print" onload="this.media='all'" rel="stylesheet"/><noscript><link href="https://fonts.googleapis.com/css2?family=Nunito+Sans:wght@300;700;900&amp;display=swap" rel="stylesheet"/></noscript>
# <meta content="Monsterhost provides fast, reliable, affordable and high-quality website hosting services. We're a Hosting Monster with unmatched security, 24/7 expert support." name="description">
# <meta content="follow, index, max-snippet:-1, max-video-preview:-1, max-image-preview:large" name="robots">
# <link href="https://monsterhost.com/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="website" property="og:type"/>
# <meta content="Fastest Web Hosting Services | Buy High Quality Hosting" property="og:title"/>
# <meta content="Monsterhost provides fast, reliable, affordable and high-quality website hosting services. We're a Hosting Monster with unmatched security, 24/7 expert support." property="og:description"/>
# <meta content="https://monsterhost.com/" property="og:url"/>
# <meta content="Monsterhost" property="og:site_name"/>
# <meta content="2022-12-16T12:46:04+00:00" property="og:updated_time"/>
# <meta content="https://monsterhost.com/wp-content/uploads/2020/12/monsterhost-dedicated-server-engineer.jpg" property="og:image"/>
# <meta content="https://monsterhost.com/wp-content/uploads/2020/12/monsterhost-dedicated-server-engineer.jpg" property="og:image:secure_url"/>
# <meta content="635" property="og:image:width"/>
# <meta content="408" property="og:image:height"/>
# <meta content="Powerful Dedicated Server Hosting - Image #3" property="og:image:alt"/>
# <meta content="image/jpeg" property="og:image:type"/>
# <meta content="MonsterHost" property="product:brand"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Fastest Web Hosting Services | Buy High Quality Hosting" name="twitter:title"/>
# <meta content="Monsterhost provides fast, reliable, affordable and high-quality website hosting services. We're a Hosting Monster with unmatched security, 24/7 expert support." name="twitter:description"/>
# <meta content="@monsterhost_com" name="twitter:site"/>
# <meta content="@monsterhost_com" name="twitter:creator"/>
# <meta content="https://monsterhost.com/wp-content/uploads/2021/03/blog-at-home-during-quarantine.jpg" name="twitter:image"/>
# <meta content="Written by" name="twitter:label1"/>
# <meta content="admin" name="twitter:data1"/>
# <meta content="Time to read" name="twitter:label2"/>
# <meta content="4 minutes" name="twitter:data2"/>
# <script class="rank-math-schema-pro" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"Place","@id":"https://monsterhost.com/#place","geo":{"@type":"GeoCoordinates","latitude":"49.581908043667575","longitude":" 6.1174824404892805"},"hasMap":"https://www.google.com/maps/search/?api=1&amp;query=49.581908043667575, 6.1174824404892805","address":{"@type":"PostalAddress","streetAddress":"14 Rue Robert Stumper","addressLocality":"Luxembourg","addressRegion":"Luxembourg","postalCode":"2557","addressCountry":"Luxembourg"}},{"@type":"Organization","@id":"https://monsterhost.com/#organization","name":"MonsterHost","url":"https://monsterhost.com","email":"Support@monsterhost.com","address":{"@type":"PostalAddress","streetAddress":"14 Rue Robert Stumper","addressLocality":"Luxembourg","addressRegion":"Luxembourg","postalCode":"2557","addressCountry":"Luxembourg"},"logo":{"@type":"ImageObject","@id":"https://monsterhost.com/#logo","url":"https://monsterhost.com/wp-content/uploads/2022/01/MonsterHost-logo-1200x627-2.jpg","contentUrl":"https://monsterhost.com/wp-content/uploads/2022/01/MonsterHost-logo-1200x627-2.jpg","caption":"MonsterHost","inLanguage":"en","width":"1200","height":"627"},"contactPoint":[{"@type":"ContactPoint","telephone":"+31102233701","contactType":"customer support"}],"location":{"@id":"https://monsterhost.com/#place"}},{"@type":"WebSite","@id":"https://monsterhost.com/#website","url":"https://monsterhost.com","name":"MonsterHost","publisher":{"@id":"https://monsterhost.com/#organization"},"inLanguage":"en","potentialAction":{"@type":"SearchAction","target":"https://monsterhost.com/?s={search_term_string}","query-input":"required name=search_term_string"}},{"@type":"ImageObject","@id":"https://monsterhost.com/wp-content/uploads/2021/01/mh-logo.png","url":"https://monsterhost.com/wp-content/uploads/2021/01/mh-logo.png","width":"289","height":"42","caption":"Monsterhost Logo","inLanguage":"en"},{"@type":"ItemPage","@id":"https://monsterhost.com/#webpage","url":"https://monsterhost.com/","name":"Fastest Web Hosting Services | Buy High Quality Hosting","datePublished":"2020-12-18T13:15:03+00:00","dateModified":"2022-12-16T12:46:04+00:00","about":{"@id":"https://monsterhost.com/#organization"},"isPartOf":{"@id":"https://monsterhost.com/#website"},"primaryImageOfPage":{"@id":"https://monsterhost.com/wp-content/uploads/2021/01/mh-logo.png"},"inLanguage":"en"},{"@type":"Product","name":"webhosting","url":"https://monsterhost.com/","description":"Monsterhost provides fast, reliable, affordable and high-quality website hosting services. We&#039;re a Hosting Monster with unmatched security, 24/7 expert support.","brand":{"@type":"Brand","name":"MonsterHost"},"image":{"@id":"https://monsterhost.com/wp-content/uploads/2021/01/mh-logo.png"},"offers":{"@type":"Offer","url":"https://monsterhost.com/","availability":"InStock"},"@id":"https://monsterhost.com/#schema-158797"}]}</script>
# <meta content="993fe34b79fde58f" name="yandex-verification"/>
# <link href="//s7.addthis.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://monsterhost.com/wp-content/cache/autoptimize/css/autoptimize_single_d2c4d33594f8d1f2738c56d0f92bab06.css" id="elementor-post-10793-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://monsterhost.com/wp-content/uploads/essential-addons-elementor/734e5f942.min.css" id="cb70d11b8-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://monsterhost.com/wp-content/cache/autoptimize/css/autoptimize_single_6ffdd14762867a78abca7bf212df6db5.css" id="tf-compiled-options-hostinza-options-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://monsterhost.com/wp-content/cache/autoptimize/css/autoptimize_single_741448b3f548052fec9a235f20aace52.css" id="elementor-post-3782-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://monsterhost.com/wp-content/cache/autoptimize/css/autoptimize_single_c27c890d8c935ad0aa317ecc01f17401.css" id="elementor-global-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="https://monsterhost.com/wp-content/cache/autoptimize/css/autoptimize_single_9130d962a168fb71035cfc9a63732358.css" id="elementor-post-11421-css" media="all" rel="stylesheet" type="text/css"/>
# <script id="jquery-core-js" src="https://monsterhost.com/wp-content/plugins/enable-jquery-migrate-helper/js/jquery/jquery-1.12.4-wp.js" type="text/javascript"></script>
# <script id="jquery-migrate-js" src="https://monsterhost.com/wp-content/plugins/enable-jquery-migrate-helper/js/jquery-migrate/jquery-migrate-1.4.1-wp.js" type="text/javascript"></script>
# <link href="https://monsterhost.com/xmlrpc.php" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="https://monsterhost.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <link href="https://monsterhost.com/" rel="shortlink"/>
# <meta content="wordpress-plugin" name="onesignal"/>
# <script>
#
#       window.OneSignal = window.OneSignal || [];
#
#       OneSignal.push( function() {
#         OneSignal.SERVICE_WORKER_UPDATER_PATH = "OneSignalSDKUpdaterWorker.js.php";
#                       OneSignal.SERVICE_WORKER_PATH = "OneSignalSDKWorker.js.php";
#                       OneSignal.SERVICE_WORKER_PARAM = { scope: "/" };
#         OneSignal.setDefaultNotificationUrl("https://monsterhost.com");
#         var oneSignal_options = {};
#         window._oneSignalInitOptions = oneSignal_options;
#
#         oneSignal_options['wordpress'] = true;
# oneSignal_options['appId'] = '6f585465-2169-4702-bbb9-edbe9cde6110';
# oneSignal_options['allowLocalhostAsSecureOrigin'] = true;
# oneSignal_options['welcomeNotification'] = { };
# oneSignal_options['welcomeNotification']['title'] = "";
# oneSignal_options['welcomeNotification']['message'] = "";
# oneSignal_options['path'] = "https://monsterhost.com/wp-content/plugins/onesignal-free-web-push-notifications/sdk_files/";
# oneSignal_options['safari_web_id'] = "web.onesignal.auto.1997779e-e1de-41f4-ac74-4543cfbf0412";
# oneSignal_options['promptOptions'] = { };
#                 OneSignal.init(window._oneSignalInitOptions);
#                 OneSignal.showSlidedownPrompt();      });
#
#       function documentInitOneSignal() {
#         var oneSignal_elements = document.getElementsByClassName("OneSignal-prompt");
#
#         var oneSignalLinkClickHandler = function(event) { OneSignal.push(['registerForPushNotifications']); event.preventDefault(); };        for(var i = 0; i < oneSignal_elements.length; i++)
#           oneSignal_elements[i].addEventListener('click', oneSignalLinkClickHandler, false);
#       }
#
#       if (document.readyState === 'complete') {
#            documentInitOneSignal();
#       }
#       else {
#            window.addEventListener("load", function(event){
#                documentInitOneSignal();
#           });
#       }
#     </script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-NJW8QVR');</script><link href="https://monsterhost.com/wp-content/uploads/2022/02/cropped-mh-logo-512px-32x32.png" rel="icon" sizes="32x32"/>
# <link href="https://monsterhost.com/wp-content/uploads/2022/02/cropped-mh-logo-512px-192x192.png" rel="icon" sizes="192x192"/>
# <link href="https://monsterhost.com/wp-content/uploads/2022/02/cropped-mh-logo-512px-180x180.png" rel="apple-touch-icon"/>
# <meta content="https://monsterhost.com/wp-content/uploads/2022/02/cropped-mh-logo-512px-270x270.png" name="msapplication-TileImage"/>
# <style id="wp-custom-css" type="text/css">
# 			/* Basic setup for the whole theme */
# body,
# .pricing-body h2 sup,
# blockquote::before,
# .author-data h5,
# .xs-comments-area .comment-author a,
# .slider-tigger h5,
# .slider-container .btn,
# .xs-heading .heading-sub-title,
# .main-nav-tab-2 li a,
# .xs-accordion>.card>.card-header>a,
# h1,
# h2,
# h3,
# .h3,
# h4,
# .elementor-widget-text-editor,
# .header-dark .xs-menus .nav-menu>li>a,
# .elementor-widget-heading .elementor-heading-title,
# .elementor-325 .elementor-element.elementor-element-481a1cd .elementor-icon-list-item,
# .elementor-widget-button .elementor-button,
# .elementor-widget-toggle .elementor-toggle .elementor-toggle-title,
# .elementor-widget-icon-list .elementor-icon-list-item,
# .elementor-widget-image-box .elementor-image-box-content .elementor-image-box-description,
# .elementor-widget-icon-box .elementor-icon-box-content .elementor-icon-box-description,
# .elementor-widget-toggle .elementor-toggle .elementor-tab-content {
# 	font-family: 'Nunito Sans', sans-serif;
# }
#
# p, span, small, strong, a {
# 	letter-spacing: 0!important;
# }
# p,
# li,
# .elementor-button {
# 	font-size: 20px;
# }
# h1 {
# 	font-size: 58px;
# 	line-height: 72px!important;
# 	font-weight: 900!important;
# }
# h2,
# .xs-heading .heading-title,
# .ekit-wid-con .elementskit-section-title {
# 	font-size: 38px;
# 	line-height: 50px!important;
# 	font-weight: 700!important;
# }
# h3, .h3 {
# 	font-size: 26px;
# 	line-height: 30px!important;
# 	font-weight: 700!important;
# 	margin-bottom: 0px;
# }
# .xs-heading .heading-sub-title,
# .xs-title,
# h4 {
# 	font-size: 20px;
# 	font-weight: 700!important;
# }
# .elementor p a {
# 	color: #000;
# 	text-decoration: underline;
# }
# .elementor p a:hover {
# 	color: #000;
# 	text-decoration: none;
# }
# .arrow-cta-header svg {
# 	font-size: 15px;
# }
# .arrow-cta-footer svg {
# 	font-size: 18px;
# }
#  #frame-title {
#         font-size: 50px;
#     }
# a:active, a:focus, a:visited {
# 	text-decoration: none;
# }
#
# .home .elementor-widget-video:before {
# 	content: "\25CF\25CF\25CF";
#     text-align: right;
#     padding: 5px;
#     padding-left: 10px;
#     border-bottom: 1px solid #C8B294;
#     display: block;
#     color: #777;
#     line-height: 5px;
#     background-color: #fff;
# 		border-radius: 5px 5px 0 0;
# }
#
# .fill-animation a {
#         background: linear-gradient(to right, #D53D6C 50%, transparent 50%);
#       background-size: 201% 100%;
#       background-position: right bottom;
#       transition: all .5s ease-out;
#     }
#     .fill-animation a:hover {
#       background-position: left bottom;
#     }
#
# a.elementor-toggle-title:hover {
# 	text-decoration: none;
# }
#
# .xs-footer-section.footer-v2 .footer-widget .menu>li>a {
# 	color: #fff;
# }
# .xs-footer-section.footer-v2 .footer-widget .menu>li>a:hover {
#  text-decoration: underline;
# }
# .xs-single-pricing,
# .xs-single-pricing.active {
# 	    box-shadow: 0px 10px 25px 0px rgba(0, 0, 0, 0.3);
# }
#
# .ekit-template-content-footer a,
# .ekit-template-content-footer a:visited {
# 	color: #000!important;
# 	font-weight: 300!important;
# 	text-decoration: none!important;
# }
#
# .ekit-template-content-footer a:hover {
# 	color: #000!important;
# 	text-decoration: underline!important;
# }
#
# .ekit-template-content-footer p,
# .ekit-template-content-footer li,
# .ekit-template-content-footer .elementor-button {
# 	font-size: 18px;
# }
# .xs-top-bar p,
# .xs-top-bar li,
# .xs-top-bar .elementor-button{
# 	font-size: 14px;
# }
# .xs-top-bar {
# 	padding: 10px 0;
# }
# .xs-menus .nav-menu>li>a {
# 	cursor: pointer;
# 	padding: 30px;
# }
# .xs-menus .nav-menu>li>a:before {
# 	background-color: #0092EA;
# }
# .xs-menus .nav-menu>li>a,
# .xs-menu-tools>li>a {
# 	color: #000;
# }
# .xs-menu-tools li {
# 	list-style:none;
# 	font-size: 16px;
# 	display: flex;
# 	align-items: center;
# }
# .xs-menu-tools li a {
# 	margin-left: 5px;
# }
#
# .xs-menu-tools li:hover a,
# .xs-menu-tools li:hover i {
# 	text-decoration: none;
# 	color: #D53D6C;
# }
# .xs-menu-tools ul {
# 	padding-left: 0px;
# 	margin-bottom:0!important;
# }
# .xs-menus .nav-menu .xs-icon-menu .single-menu-item a:hover,
# .xs-menus .nav-menu .xs-icon-menu .single-menu-item a:hover *,
# .xs-menus .nav-menu>li>a:hover,
# .xs-menu-tools>li>a:hover {
# 		color: #D53D6C;
# 	text-decoration:none;
# }
#
# .xs-menus .nav-menu>li{
# 	margin-right: 25px;
# }
#
# .xs-menus .nav-menu>li>a .submenu-indicator-chevron {
#     border-color: transparent #000 #000 transparent;
# }
#
# @media only screen and (min-width: 991px) {
# 	.xs-megamenu > .nav-submenu {
# 		transform: translateX(50%);
# 	}
# }
#
# @media only screen and (max-width: 991px) {
# 	.megamenu-content h2 {
# 		font-size: 18px!important;
# 	}
# }
#
# .xs-menus .nav-menu .xs-icon-menu .single-menu-item a i {
# 	top: 0;
# }
#
# .discount-price {
# 	font-weight: 400;
# 	line-height: 30px;
# }
#
# /* blog banner height change */
# .blog .xs-banner,
# .post-template-default .xs-banner,
# .archive.category .xs-banner,
# .archive.author .xs-banner,
# .tag .xs-banner {
#     min-height: 160px!important;
# }
# .blog .xs-banner.inner-banner .banner-title,
# .post-template-default .xs-banner.inner-banner .banner-title,
# .archive.category .xs-banner.inner-banner .banner-title,
# .archive.author .xs-banner.inner-banner .banner-title,
# .tag .xs-banner.inner-banner .banner-title {
# 	text-transform: capitalize;
# }
#
# .blog  > div + section + section,
# .post-template-default > div + section + section,
# .archive.category > div + section + section,
# .archive.author > div + section + section,
# .tag > div + section + section {
# 	border-bottom: 1px solid #000;
# }
#
#
# .blog .xs-banner .container,
# .post-template-default .xs-banner .container,
# .archive .xs-banner .container,
# .archive.author .xs-banner .container {
#     padding-top: 20px;
# }
#
# .blog .xs-banner .container h1,
# .post-template-default .xs-banner .container h1,
# .archive .xs-banner .container h1,
# .archive.author .xs-banner .container h1 {
# 	font-size: 48px;
# }
# .archive.tag .xs-banner .container {
# 	padding-top: 0;
# }
# .post-template-default .xs-section-padding {
# 	padding: 50px 0;
# }
#
# .pricing-header .xs-title {
# 	font-weight: bold;
# }
#
# .xs-pricing-group .nav-tabs {
#     margin-bottom: 100px;
# }
#
# .xs-single-pricing .pricing-img-block {
# 	margin-left: 0;
# }
#
# .elementor-widget-video .xs-bg-black {
# 	display: none;
# }
# .xs-header .container {
# 	max-width: 100%;
# 	padding: 0 100px;
# }
# .xs-menus.ml-auto {
#     margin-left: auto!important;
#     margin-right: auto!important;
# }
#
# #login {
# 	display: flex;
# 	align-items: center;
# }
# #login svg {
# 	height: 18px;
# }
#
# #login:hover {
# 	color: #D53D6C;
# 	text-decoration: none;
# }
#
# .nav-menu li a {
# 	transition: none;
# }
#
# .xs-menus .nav-menu li:hover > a,
# .xs-menus .nav-menu li > a:hover {
# 	color: #fff;
# }
# .xs-menus .nav-menu li {
# 	padding: 0;
# }
# .xs-menus .nav-menu li {
#     margin-right: 0;
# }
# .xs-menus .nav-menu > li:hover {
# 	background-color: #D53D6C;
# 	cursor: pointer;
# }
# .xs-menus .nav-menu>li>a::before {
# 	content: none;
# }
# #login:hover svg {
# 	fill: #D53D6C;
# }
#
# .xs-menu-tools {
# 	padding: 0;
# 	display: flex;
# 	justify-content: flex-end;
# 	align-items: center;
# }
#
# .xs-menu-tools {
# 	max-width: 200px;
# 	width: 100%;
# }
#
# @media only screen and (min-width: 1100px) {
# 	.xs-header .xs-menu-tools {
#     padding-left: 0px;
# }
#
# }
#
#
# .pricing-img-block img {
#     height: 100px;
# 		margin-bottom: 30px;
# }
#
# .elementor-toggle-item:not(:last-child) {
# 	border-bottom: 1px solid #000;
# 	padding-bottom: 5px;
# }
# .elementor-toggle-title {
# 	padding-right: 10px;
# }
#
# @media only screen and (max-width: 991px) {
# 	.nav-toggle:before {
# 		background-color: #000;
#     box-shadow: 0 0.5em 0 0 #000, 0 1em 0 0 #000;
# 	}
# 	.elementor-section {
# 		overflow:visible;
# 	}
# 	.elementor-top-section img {
# 		max-width: 60%;
# 	}
# 	.elementor-325 .elementor-element.elementor-element-143c67>.elementor-element-populated {
# 		padding: 0;
# 	}
# }
#
# .banner-404 {
# 	background: rgba(207, 216, 220, 0.2)!important;
# 	min-height: 100%;
# 	padding: 0 10%;
# 	padding-top: 5%;
# }
#
# .banner-404 .banner-title {
# 	color: #000;
# 	padding-right: 15%;
# 	margin-bottom: 40px;
# }
#
# .banner-404 .icon-bg {
# 	background-image:none;
# }
#
# .banner-404 a {
# 	border-radius: 0;
# 	background-color: #000;
# }
#
# .banner-404 a::before {
# 	content: none;
# }
#
# .banner-404 a:hover {
# 	transform: scale(1.1);
# 	background-color: #000;
# }
#
# .post-body .entry-title a:hover,
# .xs-blog-list.blog-lsit-style-2 .post .post-body .post-meta>span i,
# a:hover,
# .post-body a,
# .post-navigation span:hover, .post-navigation h3:hover,
# .post-navigation i,
# .widget-posts .widget-post .entry-title a:hover,
# .post-body .post-meta a:hover,
# .post-body a:hover,
# .xs-blog-list.blog-lsit-style-2 .post .post-body .post-meta>span>a:hover,
# .post-body .post-footer a:hover {
# 	text-decoration: underline;
# 	color: #000;
# }
#
#
# a.elementor-button-link:hover {
# 	text-decoration: none;
# }
#
# .post-body .entry-content a {
# 	text-decoration: underline;
# }
#
# .post-body .entry-content a:hover {
# 	text-decoration: none;
# }
#
# .entry-thumbnail img {
# 	width: auto!important;
# 	max-height: fit-content;
# }
# .post-body .post-meta>span, .post-body .post-meta a,
# .post-body .post-footer a {
# 	color: #000;
# }
#
# .blog .elementor-2656 .elementor-element.elementor-element-2c00371,
# .post-template-default .elementor-2656 .elementor-element.elementor-element-2c00371,
# .archive .elementor-2656 .elementor-element.elementor-element-2c00371 {
#     padding: 70px 0px 100px 0px;
# }
#
# .discount-price {
# 	font-weight: 400;
# 	line-height: 30px;
# }
#
# .xs-single-pricing {
# 	padding: 40px 10px;
# }
# .btn {
# 	font-size: 20px;
# 	border-radius: 50px;
# }
#
# .elementor-widget-heading .elementor-heading-title {
# 	font-weight: 700;
# }
#
# .pricing-body h2 sup {
# 	left: -3px;
# }
#
# b, strong {
# 	font-weight: 700;
# }
#
# .xs-menus .nav-brand img {
# 	max-height: 48px;
# }
#
# blockquote:before {
#     font-family: "iconfont"!important;
# }
#
# .elementor-toggle .elementor-tab-title {
#     padding: 15px 15px 15px 0;
# }
#
# .footer-main {
# 	padding-top: 190px;
# }
#
# .elementor-widget-icon-box .elementor-icon-box-content .elementor-icon-box-description {
# 	font-weight: 300;
# }
# #menu-item-5618 {
# 	display: none;
# }
#
# .row {
# display: flex;
# display: -ms-flexbox;
# display: -webkit-box;
# }
#
# .nav-menu > li.xs-megamenu {
#     position: relative;
# }
#
# @media only screen and (max-width: 1400px) and (min-width: 1024px) {
# 	h1 {
# 		font-size: 38px!important;
# 		line-height: 45px!important;
# 	}
# }
#
# @media only screen and (max-width: 1600px) {
# 	.xs-menu-tools {
# 		max-width: 18px;
# 	}
# }
#
# @media only screen and (max-width: 991px) {
# 	.xs-menu-tools {
#     display: none;
# 	}
# 	.xs-header {
# 		padding: 10px 0;
# 	}
# 	#menu-item-5618 {
# 	display: inline-block;
# }
# 	.banner-404 {
# 		padding: 0;
# 		padding-top: 5%;
# 	}
# 	.banner-404 > div > .row {
# 		flex-direction: column-reverse;
# 	}
# 	.banner-404 .col-md-12 {
# 		width: auto;
# 	}
# 	.banner-404 .col-md-12 .xs-banner-content * {
# 		text-align: center;
# 	}
# 	.banner-404 .banner-title {
# 		padding-right: 0;
# 	}
# 	.xs_nav-portrait .nav-menus-wrapper.nav-menus-wrapper-open {
#     left: initial;
#     right: 0;
# }
# }
#
# @media only screen and (max-width: 768px) {
# 	h1 {
# 			font-size: 36px!important;
# 			line-height: 45px!important;
# 	}
#
# 	h2 {
# 			font-size: 32px!important;
# 			line-height: 41px!important;
# 			font-weight: 800!important;
# 	}
#
# 	.elementor-element .elementor-widget-container {
# 		margin: 0!important;
# 	}
# 	.row {
# 		margin-left: 0!important;
# 		margin-right: 0!important;
# 	}
# 	.domain-form ::placeholder {
# 		font-size: 16px;
# 	}
# 	.elementor-top-section img {
#     max-width: 100%;
# 	}
# 	.xs-header > .container {
# 		padding: 0;
# 	}
#
# 	.xs-menus .nav-brand img {
#     max-height: 30px;
# 	}
# 	.nav-toggle {
#     padding: 3px 2px 0;
# 	}
# }
# .elementor-tab-title {
# 		display: flex;
# 		flex-direction: row-reverse;
# 		justify-content: space-between;
# 		align-items: center;
# 	}
# .nav-menus-wrapper .elementor-icon-list-icon i {
# 	width: auto!important;
# }
# .nav-menus-wrapper h2 {
# 	line-height: 30px!important;
# }
# .xs-menus .nav-menu .xs-icon-menu .single-menu-item:not(:first-child) a {
# 	padding-top: 10px;
# }
# .xs-menus .nav-menu .xs-icon-menu .single-menu-item:not(:last-child) a {
# 	padding-bottom: 10px;
# }
# .nav-dropdown>li>a {
# 	padding: 15px 20px;
# }
# .xs-menus .nav-menu .xs-icon-menu .single-menu-item a {
# 	font-size: 18px;
# }
# .xs-menus .nav-menu .xs-icon-menu .single-menu-item > a > i {
# 	color: #707070;
# 	padding-right: 10px!important;
# }
# .megamenu-content a > span > i {
# 	padding-right: 5px!important;
# }
#
# .header .xs-header label {
# 	margin-bottom: 0;
# }
#
# .row {
# 	display: -webkit-flex;
# }
# @media only screen and (max-width: 768px) {
# 	.pricing-price h2 {
# 		font-size:50px!important;
# 		font-weight: 700!important;
# 	}
# 	.xs-single-pricing {
# 		padding-top: 20px!important;
# 	}
# 	.header {
# 		position: fixed;
# 		z-index: 9999;
# 		width: 100%;
# 		background-color: #fff;
# 		top: 0;
# 	}
# 	[data-elementor-type="wp-page"] .elementor-section-wrap:first-child {
# 		padding-top: 68px;
# 	}
# 	h1 {
# 		font-size: 32px!important;
# 		line-height: 1.5!important;
# 	}
# 	h2 {
# 		font-size: 26px!important;
# 		line-height: 1.3!important;
# 	}
# 	h3 {
# 		font-size: 22px!important;
# 		line-height: 1.3!important;
# 	}
# 	h4, h5, h6, p, ul, li, .elementor-testimonial-wrapper .elementor-testimonial-content {
# 		font-size: 18px!important;
# 	}
# }
#
# /* Fix flag stuck to language switcher */
# .wpml-ls-native {
# 	padding-left: 5px;
# }
#
# /* Blog preview image center */
# .post .post-media {
# 	text-align: center;
# }
#
# /* Line height faq titles */
# .elementor-toggle .elementor-tab-title {
# 	line-height: 1.5;
# }
#
# /* Increase size of top bar */
# #top-bar-button {
# 	background-color: rgba(0,0,0,0.3)!important;
# 	padding: 3px 10px!important;
# 	border-radius: 5px!important;
# 	transition: background 0.5s!important;
# 	color: #fff!important;
# 	margin-left: 20px;
# }
# #top-bar-button:hover {
# 	background-color: rgba(0,0,0,0.15)!important;
# 	text-decoration: none!important;
# }
# .xs-top-bar {
# 	color: #fff!important;
# 	padding: 20px 0!important;
# 	font-size: 16px!important;
# }
# .xs-top-bar span {
# 	color: #fff!important;
# }
#
# @media only screen and (max-width: 768px) {
# 	.xs-top-bar span {
# 		text-align: center;
# 	}
# 	.xs-top-bar {
# 	font-size: 14px!important;
# }
# 	#top-bar-custom {
# 		display: flex;
# 		flex-direction: column;
# 	}
# 	#top-bar-button {
# 		width: 150px;
# 		margin: 10px auto;
# 		margin-bottom: 0px;
# 		text-align: center;
# 	}
# 	[data-elementor-type="wp-page"] .elementor-section-wrap:first-child {
#     padding-top: 0!important;
# }
# 	/* fixes for bottom bar mobile */
# 	#wpfront-notification-bar {
# 		height: auto!important;
# 	}
# 	#wpfront-notification-bar table td {
# 		display: flex;
# 		flex-direction: column;
# 	}
# 	#wpfront-notification-bar .wpfront-message {
# 		margin-bottom: 5px;
# 	}
#
# }
#
# .eckb-kb-template {
# 	border-bottom: 1px solid #000;
# }
#
# .faq-table table {
#   border-collapse: collapse !important;
#   width: 100% !important;
# }
# .faq-table td, th {
#   border: 1px solid #dddddd !important;
#   text-align: left !important;
#   padding: 8px !important;
# }
# .faq-table tr:nth-child(even) {
#   background-color: #f9f9f9 !important;
# }
#
# .price-table-eqh .grid {
#     display: flex;
# }
#
# .price-table-eqh .xs-single-pricing {
#     display: flex;
#     flex-direction: column;
#     justify-content: space-between;
# 	width: 100%;
# }
# .price-table-eqh .pricing-header{
# 	    min-height: 67px;
# }
#
# /* Price div inline block display for same line text */
#
# .price-sync {
# 	display: inline-block;
# }
# .box-height{
# 	  min-height: 100%;
#     display: flex;
# }
#
# /* Select on desktop */
# #currency-wrapper {
#     position: relative;
#     display: inline-block;
# }
# #currency-wrapper:before {
#     position: absolute;
#     display: block;
#     right: 20px;
#     top: 50%;
#     transform: translateY(-50%);
#     content: '\f107';
#     font: 16px "FontAwesome";
#     color: #000;
# 	cursor: pointer;
# }
# #currency-select {
#     overflow: hidden;
# 	font-size: 16px;
#     font-weight: 300;
#     margin-left: 0;
#     padding: 30px;
#     width: 100px;
#     border: none;
#     outline: none;
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     appearance: none;
#     background-color: transparent;
#     position: relative;
#     min-height: 0;
# }
# #currency-select:hover option {
#     font-size: 16px;
#     font-weight: 300;
#     font-family: 'Nunito Sans', sans-serif;
# }
# @media only screen and (min-width: 976px) {
#     #currency-wrapper:hover {
#         cursor: pointer;
#         background-color: #d53d6c;
#     }
#     #currency-wrapper:hover #currency-select {
#         color: #fff;
#         cursor: pointer;
#     }
#     #currency-select:hover option {
#         background-color: #fff;
#         color: #000;
#     }
# }
#
# .builder-btn a{
# 	width: 100% !important;
# 	padding: 13px 0px;
# }
#
# .builder-btn a:hover{
# 	transform: scale(1.05);
# }
#
#
# /* Mobile */
# @media only screen and (max-width: 975px) {
#     #currency-wrapper {
#         position: relative;
#         width: 100%;
#         padding: 15px;
#         border-top: solid 1px #f0f0f0;
#     }
#
#     #currency-wrapper:before {
#         right: 21px;
#         top: 18px;
#         transform: none;
#     }
#
#     #currency-select {
#         position: relative;
#         width: 100%;
#         padding: 0;
#     }
# }
#
# .post-meta .post-author{
# 	pointer-events: none;
# }
#
# .post-body .entry-content a{
# 	color: #26998D;
# 	text-decoration: underline;
# }
# .post-body .entry-content a: hover{
# 	color: #26998D;
# 	text-decoration: none;
# }
#
# /*Hosted Exchange*/
# /****************/
# .microsoft-pt-btn a{
# 	width: 100% !important;
# }
# @media only screen and (min-width:768px){
# 	.block-one{
# background-image: url(https://monsterhost.com/wp-content/uploads/2022/04/hosting-co-uk-microsoft-exchange-online.jpg);
#     background-size: cover;
#     background-repeat: no-repeat;
#     background-position: center center;
# }
#
# 	.block-second{
# background-image: url(https://monsterhost.com/wp-content/uploads/2022/04/hosting-co-uk-microsoft-exchange-life-balance.jpg);
#     background-size: cover;
#     background-repeat: no-repeat;
#     background-position: center center;
# }
#
# .block-three{
# background-image: url(https://monsterhost.com/wp-content/uploads/2022/04/hosting-co-uk-microsoft-exchange-mailbox.jpg);
#     background-size: cover;
#     background-repeat: no-repeat;
#     background-position: center center;
# }
#
# 	.block-four{
# background-image: url(https://monsterhost.com/wp-content/uploads/2022/04/hosting-co-uk-microsoft-exchange-calendar.jpg);
#     background-size: cover;
#     background-repeat: no-repeat;
#     background-position: center center;
# }
# 	/*for 365 pages*/
# 	.block-one-365{
# background-image: url(https://monsterhost.com/wp-content/uploads/2022/06/be-productive-office-365.jpg);
#     background-size: cover;
#     background-repeat: no-repeat;
#     background-position: center center;
# }
# 	.block-second-365{
# background-image: url(https://monsterhost.com/wp-content/uploads/2022/06/protect-your-company.jpg);
#     background-size: cover;
#     background-repeat: no-repeat;
#     background-position: center center;
# }
# 	.block-third-365{
# background-image: url(https://monsterhost.com/wp-content/uploads/2022/06/low-cost-solutions.png);
#     background-size: contain;
#     background-repeat: no-repeat;
#     background-position: center center;
# }
# }
#
# @media only screen and (max-width: 500px){
# 	.block-three-bg{
# 		background-color: #CFD8DC33 !important
# 	}
# 	.block-three-h3 h3{
# 		color: #000 !important;
# 	}
# 	.block-three-p .elementor-text-editor{
# 		color: #000 !important;
# 	}
# 	.microsoft-btn a{
# 	width: 100% !important;
# }
# }
# .modal__overlay{
# 	z-index: 99;
# }
# .rank-math-breadcrumb p{
# 	font-size: 13px;
# 	margin-bottom: 0px;
# }
# .table-res-wrap{
# 	    max-width: 100%;
#     overflow-x: scroll;
# }
# .f-14 p {
#     line-height: 22px;
# }
# .btn-pricebox a{
# 	width: 100% !important;
# }
#
# .h2-sm{
# 	font-family: 'Nunito Sans', sans-serif;
# 	color: #000;
#   font-size: 20px;
# 	letter-spacing: 0px;
# 	line-height: 30px;
# 	font-weight: 700 !important;
#
# }
#
#
# tr.row-gray td {
#     padding: 15px 8px;
#     background-color: #F3F5F6;
# }
# .table-blog td{
#     border: 1px solid rgb(0 0 0 / 54%) !important;
# }
# .price-sm .pricing-body h2{
# 	    font-size: 2.29412rem;
# }		</style>
# <noscript><style id="rocket-lazyload-nojs-css">.rll-youtube-player, [data-lazy-src]{display:none !important;}</style></noscript> </meta></meta></head>
# <body class="home page-template page-template-elementor_header_footer page page-id-11421 sidebar-active elementor-default elementor-template-full-width elementor-kit-3782 elementor-page elementor-page-11421" data-spy="scroll" data-target="#header">
# <input id="whmcsCurrencyUrl" name="whmcsCurrencyUrl" type="hidden" value="https://my.monsterhost.com"/>
# <div class="header">
# <header class="xs-header">
# <div class="container">
# <div class="row align-items-center">
# <div class="xs-logo-wraper">
# <a class="xs-logo">
# <img alt="Monsterhost" data-lazy-src="https://monsterhost.com/wp-content/uploads/2021/01/mh-logo.png" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%200%200'%3E%3C/svg%3E"/><noscript><img alt="Monsterhost" src="https://monsterhost.com/wp-content/uploads/2021/01/mh-logo.png"/></noscript>
# </a>
# </div>
# <nav class="xs-menus ml-auto">
# <div class="nav-header">
# <a class="nav-brand" href="https://monsterhost.com/">
# <img alt="Monsterhost" data-lazy-src="https://monsterhost.com/wp-content/uploads/2021/01/mh-logo.png" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%200%200'%3E%3C/svg%3E"/><noscript><img alt="Monsterhost" src="https://monsterhost.com/wp-content/uploads/2021/01/mh-logo.png"/></noscript>
# </a>
# <div class="nav-toggle"></div>
# </div>
# <div class="nav-menus-wrapper"><ul class="nav-menu" id="main-menu"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-7186 single-menu-item" id="menu-item-7186"><a title="Hosting">Hosting</a>
# <ul class="nav-dropdown xs-icon-menu nav-submenu" role="menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-mega_menu menu-item-10869 single-menu-item" id="menu-item-10869"><div class="megamenu-content"> <div class="elementor elementor-10070 elementor-7185" data-elementor-id="10070" data-elementor-settings="[]" data-elementor-type="wp-post">
# <div class="elementor-inner">
# <div class="elementor-section-wrap">
# <section class="elementor-section elementor-top-section elementor-element elementor-element-d4a84ad elementor-section-boxed elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="d4a84ad" data-settings='{"background_background":"classic"}' id="mega-menu">
# <div class="elementor-container elementor-column-gap-default">
# <div class="elementor-row">
# <div class="elementor-column elementor-col-100 elementor-top-column elementor-element elementor-element-a493b9a" data-element_type="column" data-id="a493b9a">
# <div class="elementor-column-wrap elementor-element-populated">
# <div class="elementor-widget-wrap">
# <section class="elementor-section elementor-inner-section elementor-element elementor-element-ec2e6b3 elementor-section-boxed elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="ec2e6b3">
# <div class="elementor-container elementor-column-gap-default">
# <div class="elementor-row">
# <div class="elementor-column elementor-col-50 elementor-inner-column elementor-element elementor-element-6574845" data-element_type="column" data-id="6574845">
# <div class="elementor-column-wrap elementor-element-populated">
# <div class="elementor-widget-wrap">
# <div class="elementor-element elementor-element-ef04a83 elementor-widget elementor-widget-text-editor" data-element_type="widget" data-id="ef04a83" data-widget_type="text-editor.default">
# <div class="elementor-widget-container">
# <div class="elementor-text-editor elementor-clearfix"><div class="h2-sm elementor-heading-title elementor-size-default">Hosting</div></div>
# </div>
# </div>
# <div class="elementor-element elementor-element-fda1385 elementor-widget-divider--view-line elementor-widget elementor-widget-divider" data-element_type="widget" data-id="fda1385" data-widget_type="divider.default">
# <div class="elementor-widget-container">
# <div class="elementor-divider">
# <span class="elementor-divider-separator">
# </span>
# </div>
# </div>
# </div>
# <div class="elementor-element elementor-element-03c44aa wp-menus elementor-widget elementor-widget-wp-widget-nav_menu" data-element_type="widget" data-id="03c44aa" data-widget_type="wp-widget-nav_menu.default">
# <div class="elementor-widget-container">
# <div class="menu-hosting-mega-menu-container"><ul class="menu" id="menu-hosting-mega-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-15560" id="menu-item-15560"><a href="https://monsterhost.com/web-hosting/">Web Hosting</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-15562" id="menu-item-15562"><a href="https://monsterhost.com/wordpress-hosting/">WordPress Hosting</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-15561" id="menu-item-15561"><a href="https://monsterhost.com/reseller-hosting/">Reseller Hosting</a></li>
# </ul></div> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="elementor-column elementor-col-50 elementor-inner-column elementor-element elementor-element-be3f5c6" data-element_type="column" data-id="be3f5c6">
# <div class="elementor-column-wrap elementor-element-populated">
# <div class="elementor-widget-wrap">
# <div class="elementor-element elementor-element-0ba034d elementor-widget elementor-widget-text-editor" data-element_type="widget" data-id="0ba034d" data-widget_type="text-editor.default">
# <div class="elementor-widget-container">
# <div class="elementor-text-editor elementor-clearfix"><div class="h2-sm elementor-heading-title elementor-size-default">Servers<span style="background-color:#707070;color:#fff;padding: 2px 5px;font-size:16px;border-radius:5px;margin-left:10px;">PRO</span></div></div>
# </div>
# </div>
# <div class="elementor-element elementor-element-94e92eb elementor-widget-divider--view-line elementor-widget elementor-widget-divider" data-element_type="widget" data-id="94e92eb" data-widget_type="divider.default">
# <div class="elementor-widget-container">
# <div class="elementor-divider">
# <span class="elementor-divider-separator">
# </span>
# </div>
# </div>
# </div>
# <div class="elementor-element elementor-element-488d367 wp-menus elementor-widget elementor-widget-wp-widget-nav_menu" data-element_type="widget" data-id="488d367" data-widget_type="wp-widget-nav_menu.default">
# <div class="elementor-widget-container">
# <div class="menu-servers-mega-menu-container"><ul class="menu" id="menu-servers-mega-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-15565" id="menu-item-15565"><a href="https://monsterhost.com/vps-hosting/">VPS Hosting</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-15563" id="menu-item-15563"><a href="https://monsterhost.com/dedicated-servers/">Dedicated Servers</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-21541" id="menu-item-21541"><a href="https://monsterhost.com/backup/">Cloud Backup</a></li>
# </ul></div> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="elementor-section elementor-inner-section elementor-element elementor-element-a8da74e elementor-section-boxed elementor-section-height-default elementor-section-height-default" data-element_type="section" data-id="a8da74e">
# <div class="elementor-container elementor-column-gap-default">
# <div class="elementor-row">
# <div class="elementor-column elementor-col-50 elementor-inner-column elementor-element elementor-element-e9792ff" data-element_type="column" data-id="e9792ff">
# <div class="elementor-column-wrap elementor-element-populated">
# <div class="elementor-widget-wrap">
# <div class="elementor-element elementor-element-66eafdd elementor-widget elementor-widget-text-editor" data-element_type="widget" data-id="66eafdd" data-widget_type="text-editor.default">
# <div class="elementor-widget-container">
# <div class="elementor-text-editor elementor-clearfix"><div class="h2-sm elementor-heading-title elementor-size-default">Security</div></div>
# </div>
# </div>
# <div class="elementor-element elementor-element-daf5187 elementor-widget-divider--view-line elementor-widget elementor-widget-divider" data-element_type="widget" data-id="daf5187" data-widget_type="divider.default">
# <div class="elementor-widget-container">
# <div class="elementor-divider">
# <span class="elementor-divider-separator">
# </span>
# </div>
# </div>
# </div>
# <div class="elementor-element elementor-element-b567977 wp-menus elementor-widget elementor-widget-wp-widget-nav_menu" data-element_type="widget" data-id="b567977" data-widget_type="wp-widget-nav_menu.default">
# <div class="elementor-widget-container">
# <div class="menu-security-mega-menu-container"><ul class="menu" id="menu-security-mega-menu"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-15566" id="menu-item-15566"><a href="https://monsterhost.com/website-monitoring/">Website Monitoring</a></li>
# </ul></div> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="elementor-column elementor-col-50 elementor-inner-column elementor-element elementor-element-8385af8" data-element_type="column" data-id="8385af8">
# <div class="elementor-column-wrap elementor-element-populated">
# <div class="elementor-widget-wrap">
# <div class="elementor-element elementor-element-a2edabd elementor-widget elementor-widget-html" data-element_type="widget" data-id="a2edabd" data-widget_type="html.default">
# <div class="elementor-widget-container">
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# </div>
# </div>
# </div>
# </div></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-20547 single-menu-item" id="menu-item-20547"><a title="Domains">Domains</a>
# <ul class="nav-dropdown xs-icon-menu nav-submenu" role="menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-12171 single-menu-item" id="menu-item-12171"><a href="https://monsterhost.com/domains/" title="Domain Registration"><i class="fas fa-caret-right"></i>Domain Registration</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-20548 single-menu-item" id="menu-item-20548"><a href="https://monsterhost.com/domain-transfer/" title="Domain Transfer"><i class="fas fa-caret-right"></i>Domain Transfer</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-31614 single-menu-item" id="menu-item-31614"><a href="https://monsterhost.com/domain-reseller/" title="Domain Reseller"><i class="fas fa-caret-right"></i>Domain Reseller</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-17860 single-menu-item" id="menu-item-17860"><a href="https://monsterhost.com/ssl-certificates/" title="SSL Certificates">SSL Certificates</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-32432 single-menu-item" id="menu-item-32432"><a title="Emails">Emails</a>
# <ul class="nav-dropdown xs-icon-menu nav-submenu" role="menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-32435 single-menu-item" id="menu-item-32435"><a href="https://monsterhost.com/email-marketing/" title="Email Marketing"><i class="fas fa-caret-right"></i>Email Marketing</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-32433 single-menu-item" id="menu-item-32433"><a href="https://monsterhost.com/microsoft-365/" title="Microsoft 365"><i class="fas fa-caret-right"></i>Microsoft 365</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-32434 single-menu-item" id="menu-item-32434"><a href="https://monsterhost.com/hosted-exchange/" title="Hosted Exchange"><i class="fas fa-caret-right"></i>Hosted Exchange</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-8164 single-menu-item" id="menu-item-8164"><a title="Tools">Tools</a>
# <ul class="nav-dropdown xs-icon-menu nav-submenu" role="menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-11144 single-menu-item" id="menu-item-11144"><a href="https://monsterhost.com/website-builder/" title="Sitebuilder"><i class="fas fa-caret-right"></i>Sitebuilder</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-32431 single-menu-item" id="menu-item-32431"><a href="https://monsterhost.com/seo-tool/" title="SEO Tool"><i class="fas fa-caret-right"></i>SEO Tool</a></li>
# </ul>
# </li>
# <li class="menu-item wpml-ls-slot-2 wpml-ls-item wpml-ls-item-en wpml-ls-current-language wpml-ls-menu-item wpml-ls-last-item menu-item-type-wpml_ls_menu_item menu-item-object-wpml_ls_menu_item menu-item-has-children menu-item-wpml-ls-2-en single-menu-item" id="menu-item-wpml-ls-2-en"><a href="https://monsterhost.com" title='&lt;img class="wpml-ls-flag" src="https://monsterhost.com/wp-content/plugins/sitepress-multilingual-cms/res/flags/en.png" alt="EN"&gt;&lt;span class="wpml-ls-native" lang="en"&gt;EN&lt;/span&gt;'><img alt="EN" class="wpml-ls-flag" data-lazy-src="https://monsterhost.com/wp-content/plugins/sitepress-multilingual-cms/res/flags/en.png" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%200%200'%3E%3C/svg%3E"/><noscript><img alt="EN" class="wpml-ls-flag" src="https://monsterhost.com/wp-content/plugins/sitepress-multilingual-cms/res/flags/en.png"/></noscript><span class="wpml-ls-native" lang="en">EN</span></a>
# <ul class="nav-dropdown xs-icon-menu nav-submenu" role="menu">
# <li class="menu-item wpml-ls-slot-2 wpml-ls-item wpml-ls-item-nl wpml-ls-menu-item wpml-ls-first-item menu-item-type-wpml_ls_menu_item menu-item-object-wpml_ls_menu_item menu-item-wpml-ls-2-nl single-menu-item" id="menu-item-wpml-ls-2-nl"><a href="https://monsterhost.com/nl/" title='&lt;img class="wpml-ls-flag" src="https://monsterhost.com/wp-content/plugins/sitepress-multilingual-cms/res/flags/nl.png" alt="NL"&gt;&lt;span class="wpml-ls-native" lang="nl"&gt;NL&lt;/span&gt;'><img alt="NL" class="wpml-ls-flag" data-lazy-src="https://monsterhost.com/wp-content/plugins/sitepress-multilingual-cms/res/flags/nl.png" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%200%200'%3E%3C/svg%3E"/><noscript><img alt="NL" class="wpml-ls-flag" src="https://monsterhost.com/wp-content/plugins/sitepress-multilingual-cms/res/flags/nl.png"/></noscript><span class="wpml-ls-native" lang="nl">NL</span></a></li>
# </ul>
# </li>
# <label id="currency-wrapper"><select id="currency-select" name="defaultCurrency"><option value="GBP">GBP</option><option selected="selected" value="EUR">EUR</option><option value="USD">USD</option><option value="INR">INR</option><option value="CNY">CNY</option></select></label></ul></div> </nav>
# <div class="xs-menu-tools"><ul class="menu" id="menu-login"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-11433" id="menu-item-11433"><i class="fas fa-key"></i><a href="https://monsterhost.com/login/">Login</a></li>
# </ul></div>
# </div>
# </div>
# </header>
# </div><div class="at-above-post-homepage addthis_tool" data-url="https://monsterhost.com/"></div> <div class="elementor elementor-11421 elementor-11405" data-elementor-id="11421" data-elementor-settings="[]" data-elementor-type="wp-page">
# <div class="elementor-inner">
# <div class="elementor-section-wrap">
# ...
# <div aria-labelledby="sls-modal-title" aria-modal="true" class="modal__container" role="dialog">
# <header class="modal__header">
# <form class="sls-form" data-index-url="https://monsterhost.com/wp-content/search-index.json" id="sls-form">
# <input autofocus="" id="sls-query" name="s" placeholder="Search..." type="text">
# </input></form>
# </header>
# <main class="modal__content sls-results" id="sls-results">
# <div class="sls-hide" id="sls-results-list"></div>
# <div class="sls-hide" id="sls-no-results">
# We could not find any results for your search. You can give it another try through the search form above. </div>
# </main>
# </div>
# </div>
# </div>
# <script id="sls-result-template" type="x-tmpl-sls">
#     <header class='entry-header'>
#         <h5 class='entry-title'><a href='{{ url }}'>{{ title }}</a></h5>
#         <!-- <div>{{ content }}</div> -->
#     </header>
# </script>
# <script id="pap_x2s6df8d" src="https://partner.hosting.money/scripts/o1znjg" type="text/javascript"></script>
# <script type="text/javascript">
# PostAffTracker.setAccountId('default1');
# try {
# PostAffTracker.track();
# } catch (err) { }
# </script>
# <script>
# 	if(document.querySelector('a[title="Hosting"]')) {
# 		document.querySelector('a[title="Hosting"]').setAttribute('href', 'javascript:void(0);');
# 	}
# 	if(document.querySelector('a[title="Emails"]')) {
# 		document.querySelector('a[title="Emails"]').setAttribute('href', 'javascript:void(0);');
# 	}
# 	if(document.querySelector('a[title="Tools"]')) {
# 		document.querySelector('a[title="Tools"]').setAttribute('href', 'javascript:void(0);');
# 	}
# 	document.addEventListener("DOMContentLoaded", function(){
# 		if(document.querySelector('div[data-elementor-type="wp-page"]') && (window.innerWidth <= 768)) {
# 			document.querySelector('div[data-elementor-type="wp-page"]').style = 'padding-top:' + (document.querySelector('div.header').clientHeight) + 'px';
# 		}
# 	});
#     document.querySelectorAll('.wp-menus ul.menu li').forEach((menuItem) => {
#         menuItem.innerHTML = '<span class="fas fa-caret-right"></span>' + menuItem.innerHTML;
#     });
# 	if (document.querySelectorAll('.pricing-price')) {
#     document.querySelectorAll('.pricing-price').forEach((price) => {
# 		if (price.previousElementSibling) {
#         	if (price.previousElementSibling.querySelector('.save-amount del') && price.previousElementSibling.querySelector('.save-amount + span')) {
#             	let oldPrice = parseFloat(price.previousElementSibling.querySelector('.save-amount del').innerText);
#             	if (parseFloat(price.firstElementChild.innerText.replace(/[^0-9.]/g, ''))) {
#                 	let newPrice= parseFloat(price.firstElementChild.innerText.replace(/[^0-9.]/g, ''));
#                 	let percentage = Math.round(((oldPrice - newPrice) / oldPrice) * 100);
#                 	price.previousElementSibling.querySelector('.save-amount del + span').innerHTML = 'Save ' + percentage + '%';
#             	}
# 			}
#         }
#     });
# }
#
#
# </script><script data-cfasync="false" type="text/javascript">if (window.addthis_product === undefined) { window.addthis_product = "wpp"; } if (window.wp_product_version === undefined) { window.wp_product_version = "wpp-6.2.7"; } if (window.addthis_share === undefined) { window.addthis_share = {}; } if (window.addthis_config === undefined) { window.addthis_config = {"data_track_clickback":true,"ui_atversion":"300"}; } if (window.addthis_plugin_info === undefined) { window.addthis_plugin_info = {"info_status":"enabled","cms_name":"WordPress","plugin_name":"Share Buttons by AddThis","plugin_version":"6.2.7","plugin_mode":"AddThis","anonymous_profile_id":"wp-6b840f5b071c5159f79ec5e966062763","page_info":{"template":"home","post_type":""},"sharing_enabled_on_post_via_metabox":false}; }
#                     (function() {
#                       var first_load_interval_id = setInterval(function () {
#                         if (typeof window.addthis !== 'undefined') {
#                           window.clearInterval(first_load_interval_id);
#                           if (typeof window.addthis_layers !== 'undefined' && Object.getOwnPropertyNames(window.addthis_layers).length > 0) {
#                             window.addthis.layers(window.addthis_layers);
#                           }
#                           if (Array.isArray(window.addthis_layers_tools)) {
#                             for (i = 0; i < window.addthis_layers_tools.length; i++) {
#                               window.addthis.layers(window.addthis_layers_tools[i]);
#                             }
#                           }
#                         }
#                      },1000)
#                     }());
#                 </script><link href="https://monsterhost.com/wp-content/cache/autoptimize/css/autoptimize_single_ddced29fc14081bc4eb0ec12b4ba8c76.css" id="elementor-post-10070-css" media="all" rel="stylesheet" type="text/css"/>
# <script id="serverless-search-js" src="https://monsterhost.com/wp-content/plugins/flatsite-serverless-search/dist/js/app.js" type="text/javascript"></script>
# <script id="hostinza-tweetie-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var hostinza_path = {"hostinza_script":"https:\/\/monsterhost.com\/wp-content\/plugins\/hostinza-assistance\/api\/tweet.php"};
# /* ]]> */
# </script>
# <script id="hostinza-tweetie-js" src="https://monsterhost.com/wp-content/themes/hostinza/assets/js/tweetie.js" type="text/javascript"></script>
# <script id="cb70d11b8-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var localize = {"ajaxurl":"https:\/\/monsterhost.com\/wp-admin\/admin-ajax.php","nonce":"8cd6861cf3","i18n":{"added":"Added ","compare":"Compare","loading":"Loading..."}};
# /* ]]> */
# </script>
# <script id="cb70d11b8-js" src="https://monsterhost.com/wp-content/uploads/essential-addons-elementor/734e5f942.min.js" type="text/javascript"></script>
# <script id="elementskit-framework-js-frontend-js" src="https://monsterhost.com/wp-content/plugins/elementskit-lite/libs/framework/assets/js/frontend-script.js" type="text/javascript"></script>
# <script id="elementskit-framework-js-frontend-js-after" type="text/javascript">
# 		var elementskit = {
# 			resturl: 'https://monsterhost.com/wp-json/elementskit/v1/',
# 		}
#
#
# </script>
# <script id="ekit-widget-scripts-js" src="https://monsterhost.com/wp-content/plugins/elementskit-lite/widgets/init/assets/js/widget-scripts.js" type="text/javascript"></script>
# <script id="addthis_widget-js" src="https://s7.addthis.com/js/300/addthis_widget.js?#pubid=ra-62ebbb013f9600bc" type="text/javascript"></script>
# <script id="magnific-popup-js" src="https://monsterhost.com/wp-content/themes/hostinza/assets/js/jquery.magnific-popup.min.js" type="text/javascript"></script>
# <script id="navigation-js" src="https://monsterhost.com/wp-content/themes/hostinza/assets/js/navigation.min.js" type="text/javascript"></script>
# <script id="jquery-ui-js" src="https://monsterhost.com/wp-content/themes/hostinza/assets/js/jquery-ui.min.js" type="text/javascript"></script>
# <script id="tweetie-js" src="https://monsterhost.com/wp-content/themes/hostinza/assets/js/tweetie.js" type="text/javascript"></script>
# <script id="owl-carousel-js" src="https://monsterhost.com/wp-content/themes/hostinza/assets/js/owl.carousel.min.js" type="text/javascript"></script>
# <script id="shuffle-letters-js" src="https://monsterhost.com/wp-content/themes/hostinza/assets/js/shuffle-letters.js" type="text/javascript"></script>
# <script id="ajaxchimp-js" src="https://monsterhost.com/wp-content/themes/hostinza/assets/js/jquery.ajaxchimp.min.js" type="text/javascript"></script>
# <script id="wow-js" src="https://monsterhost.com/wp-content/themes/hostinza/assets/js/wow.min.js" type="text/javascript"></script>
# <script id="hostinza-hostslide-js" src="https://monsterhost.com/wp-content/themes/hostinza/assets/js/hostslide.js" type="text/javascript"></script>
# <script id="popper-js" src="https://monsterhost.com/wp-content/themes/hostinza/assets/js/Popper.js" type="text/javascript"></script>
# <script id="hostinza-main-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var translate_array = {"load_more":"Load More"};
# var translate_array = {"load_more":"Load More"};
# /* ]]> */
# </script>
# <script id="hostinza-main-js" src="https://monsterhost.com/wp-content/themes/hostinza/assets/js/main.js" type="text/javascript"></script>
# <script id="bootstrap-js-js" src="https://monsterhost.com/wp-content/themes/hostinza/assets/js/bootstrap.min.js" type="text/javascript"></script>
# <script id="wp-embed-js" src="https://monsterhost.com/wp-includes/js/wp-embed.min.js" type="text/javascript"></script>
# <script async="async" id="remote_sdk-js" src="https://cdn.onesignal.com/sdks/OneSignalSDK.js?" type="text/javascript"></script>
# <script id="font-awesome-4-shim-js" src="https://monsterhost.com/wp-content/plugins/elementor/assets/lib/font-awesome/js/v4-shims.min.js" type="text/javascript"></script>
# <script id="elementor-webpack-runtime-js" src="https://monsterhost.com/wp-content/plugins/elementor/assets/js/webpack.runtime.min.js" type="text/javascript"></script>
# <script id="elementor-frontend-modules-js" src="https://monsterhost.com/wp-content/plugins/elementor/assets/js/frontend-modules.min.js" type="text/javascript"></script>
# <script id="jquery-ui-position-js" src="https://monsterhost.com/wp-content/plugins/enable-jquery-migrate-helper/js/jquery-ui/position.min.js" type="text/javascript"></script>
# <script id="elementor-dialog-js" src="https://monsterhost.com/wp-content/plugins/elementor/assets/lib/dialog/dialog.min.js" type="text/javascript"></script>
# <script id="elementor-waypoints-js" src="https://monsterhost.com/wp-content/plugins/elementor/assets/lib/waypoints/waypoints.min.js" type="text/javascript"></script>
# <script id="share-link-js" src="https://monsterhost.com/wp-content/plugins/elementor/assets/lib/share-link/share-link.min.js" type="text/javascript"></script>
# <script id="swiper-js" src="https://monsterhost.com/wp-content/plugins/elementor/assets/lib/swiper/swiper.min.js" type="text/javascript"></script>
# <script id="elementor-frontend-js-before" type="text/javascript">
# var elementorFrontendConfig = {"environmentMode":{"edit":false,"wpPreview":false,"isScriptDebug":false,"isImprovedAssetsLoading":false},"i18n":{"shareOnFacebook":"Share on Facebook","shareOnTwitter":"Share on Twitter","pinIt":"Pin it","download":"Download","downloadImage":"Download image","fullscreen":"Fullscreen","zoom":"Zoom","share":"Share","playVideo":"Play Video","previous":"Previous","next":"Next","close":"Close"},"is_rtl":false,"breakpoints":{"xs":0,"sm":480,"md":768,"lg":1025,"xl":1440,"xxl":1600},"version":"3.1.1","is_static":false,"experimentalFeatures":[],"urls":{"assets":"https:\/\/monsterhost.com\/wp-content\/plugins\/elementor\/assets\/"},"settings":{"page":[],"editorPreferences":[]},"kit":{"global_image_lightbox":"yes","lightbox_enable_counter":"yes","lightbox_enable_fullscreen":"yes","lightbox_enable_zoom":"yes","lightbox_enable_share":"yes","lightbox_title_src":"title","lightbox_description_src":"description"},"post":{"id":11421,"title":"Fastest%20Web%20Hosting%20Services%20%7C%20Buy%20High%20Quality%20Hosting","excerpt":"","featuredImage":"https:\/\/monsterhost.com\/wp-content\/uploads\/2021\/01\/mh-logo.png"}};
# </script>
# <script id="elementor-frontend-js" src="https://monsterhost.com/wp-content/plugins/elementor/assets/js/frontend.min.js" type="text/javascript"></script>
# <script id="xs-main-elementor-js" src="https://monsterhost.com/wp-content/themes/hostinza/assets/js/elementor.js" type="text/javascript"></script>
# <script id="animate-circle-js" src="https://monsterhost.com/wp-content/plugins/elementskit-lite/widgets/init/assets/js/animate-circle.js" type="text/javascript"></script>
# <script id="elementskit-elementor-js-extra" type="text/javascript">
# /* <![CDATA[ */
# var ekit_config = {"ajaxurl":"https:\/\/monsterhost.com\/wp-admin\/admin-ajax.php","nonce":"f419169aad"};
# /* ]]> */
# </script>
# <script id="elementskit-elementor-js" src="https://monsterhost.com/wp-content/plugins/elementskit-lite/widgets/init/assets/js/elementor.js" type="text/javascript"></script>
# <script id="preloaded-elements-handlers-js" src="https://monsterhost.com/wp-content/plugins/elementor/assets/js/preloaded-elements-handlers.min.js" type="text/javascript"></script>
# <script id="zonat_switcher_new-js" src="https://monsterhost.com/wp-content/plugins/wordpressplugin-wppricesync/dist/zonat.switcher.js" type="text/javascript"></script>
# <script>window.lazyLoadOptions=[{elements_selector:"img[data-lazy-src],.rocket-lazyload",data_src:"lazy-src",data_srcset:"lazy-srcset",data_sizes:"lazy-sizes",class_loading:"lazyloading",class_loaded:"lazyloaded",threshold:300,callback_loaded:function(element){if(element.tagName==="IFRAME"&&element.dataset.rocketLazyload=="fitvidscompatible"){if(element.classList.contains("lazyloaded")){if(typeof window.jQuery!="undefined"){if(jQuery.fn.fitVids){jQuery(element).parent().fitVids()}}}}}},{elements_selector:".rocket-lazyload",data_src:"lazy-src",data_srcset:"lazy-srcset",data_sizes:"lazy-sizes",class_loading:"lazyloading",class_loaded:"lazyloaded",threshold:300,}];window.addEventListener('LazyLoad::Initialized',function(e){var lazyLoadInstance=e.detail.instance;if(window.MutationObserver){var observer=new MutationObserver(function(mutations){var image_count=0;var iframe_count=0;var rocketlazy_count=0;mutations.forEach(function(mutation){for(var i=0;i<mutation.addedNodes.length;i++){if(typeof mutation.addedNodes[i].getElementsByTagName!=='function'){continue}
# if(typeof mutation.addedNodes[i].getElementsByClassName!=='function'){continue}
# images=mutation.addedNodes[i].getElementsByTagName('img');is_image=mutation.addedNodes[i].tagName=="IMG";iframes=mutation.addedNodes[i].getElementsByTagName('iframe');is_iframe=mutation.addedNodes[i].tagName=="IFRAME";rocket_lazy=mutation.addedNodes[i].getElementsByClassName('rocket-lazyload');image_count+=images.length;iframe_count+=iframes.length;rocketlazy_count+=rocket_lazy.length;if(is_image){image_count+=1}
# if(is_iframe){iframe_count+=1}}});if(image_count>0||iframe_count>0||rocketlazy_count>0){lazyLoadInstance.update()}});var b=document.getElementsByTagName("body")[0];var config={childList:!0,subtree:!0};observer.observe(b,config)}},!1)</script><script async="" data-no-minify="1" src="https://monsterhost.com/wp-content/plugins/wp-rocket/assets/js/lazyload/17.5/lazyload.min.js"></script>
# </body>
# </html>
#
# <Response [404]>
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Online Shopping India Mobile, Cameras, Lifestyle &amp; more Online @ Flipkart.com</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width,minimum-scale=1,user-scalable=no" name="viewport"/>
# <style type="text/css">
#         html,
#         body {
#             font-family: Roboto, Arial, sans-serif;
#             height: 100%;
#             margin: 0;
#         }
#
#         .button {
#             background-color: #2874f0;
#             color: #fff;
#             padding: 10px 20px;
#             text-align: center;
#             box-shadow: 0 2px 4px 0 rgba(0, 0, 0, .2);
#             cursor: pointer;
#             font-size: 16px;
#             margin-top: 25px;
#             border-radius: 2px;
#             text-decoration: none;
#         }
#     </style>
# </head>
# <body>
# <div style="background-color:#2874f0; height:78px; text-align:center;">
# <div style="width: 100%; margin: 0 auto; padding-top: 2px; text-align:left;">
# <div style="margin-top: 15px; text-align: center">
# <img src="http://img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" style="border: none;" width="149"/>
# </div>
# </div>
# </div>
# <div style="text-align: center; font-size: 14px; padding: 20px;">
# <div>
# <img alt="" id="IMG_3" src="https://img1a.flixcart.com/www/linchpin/fk-cp-zion/img/error-500_f9bbb4.png" style="width: 450px; max-width: 100%;"/>
# <div style="font-size: 1.3em; padding-top: 10px; margin-bottom: 35px">Unfortunately the page you are looking
#                 for has been moved or deleted</div>
# <a class="button" href="/">GO TO HOMEPAGE</a>
# </div>
# </div>
# </body>
# </html>

# %%
products = product1 + product2
df= pd.DataFrame(products)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df['price'] = df['price'].str.replace('$','').astype(float)
df['gst_rate'] = df['gst_rate'].fillna(0)

average_gst_rate_by_category = df.groupby('category')['gst_rate'].mean()
print(average_gst_rate_by_category)

df.to_csv('products.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# C:\Users\ROHITR~1\AppData\Local\Temp/ipykernel_4088/3948064979.py in <module>
# ----> 1 df['price'] = df['price'].str.replace('$','').astype(float)
#       2 df['gst_rate'] = df['gst_rate'].fillna(0)
#       3
#       4 average_gst_rate_by_category = df.groupby('category')['gst_rate'].mean()
#       5 print(average_gst_rate_by_category)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'price'

# %%
with open('gst_rates.csv','r') as file:
    reader = csv.reader(file)
    next(reader)
    for row in reader:
        gst_rates[row[0]] == float(row[1])
